# %% [markdown]
# <a href="https://colab.research.google.com/github/Octa-Ibarra/Rl_Assigment7/blob/main/REINFORCE.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # REINFORCE
#
# Este tutorial pretende introducir uno de los primeros algoritmos de gradiente de política: REINFORCE. Nuevamente, para ilustrar el funcionamiento y desempeño del algoritmo, se hará uso de un problema basado en un juego de Atari, donde el agente aprenderá directamente de las imágenes del juego. Al mismo tiempo, se profundizará en los beneficios que tiene la utilización de <i>baselines</i> durante el entrenamiento. Para ello, en este notebook se utiliza la librería Gymnasium, que incluye el juego de <i>Atlantis</i>, y una implementación de REINFORCE realizada para PyTorch.

# %% [markdown]
# # Marco Teórico
#
# Hasta ahora, los algoritmos de aprendizaje por refuerzo que se han explorado se basan en aprender y estimar una función de valor para cada acción, por lo que reciben el nombre de métodos de valor-acción (<i>action-value methods</i>). Es decir, las políticas aprendidas en estos métodos dependen directamente de los estimativos de la función de valor-acción ($Q(s,a)$). Sin embargo, existe otra familia de algoritmos que siguen un método de gradiente de política (<i>policy gradient methods</i>), que directamente aprenden una política parametrizada con la capacidad de seleccionar acciones sin la necesidad de estimar una función de valor. Una función de valor puede ser todavía utilizada para aprender el parámetro de la política, pero no se requiere para seleccionar la acción. [1]
#
# Por convención de notación, se utiliza $\theta$ para referirse a un vector de parámetros de la política. Entonces se puede escribir que la política, corresponde a la probabilidad de elegir una acción dado un estado y el vector de parámetros: $\pi(a|s,\theta) = Pr(A_t=a|S_t=s, \theta_t=\theta)$. La forma en que un algoritmo aprende y actualiza el vector de parámetros $\theta$ se basa en el gradiente de alguna métrica de desempeño escalar $J(\theta)$. Este método busca maximizar el desempeño, así que se tiene un ascenso de gradiente en $J$, como se muestra en la Ecuación (1). Se utiliza la notación $\widehat{\nabla J(\theta_t)}$ para denotar que el gradiente en realidad se calcula utilizando un estimativo estocástico. [1]
#
# $\theta_{t+1}=\theta + \alpha \widehat{\nabla J(\theta_t)}$ &emsp;&emsp;&emsp;$(1)$
#
# Otro elemento importante a tener en cuenta es el teorema de gradiente de política (policy gradient theorem), mostrado en la Ecuación (2). En este teorema, se establece que existe una proporcionalidad entre el gradiente de la función $J(\theta)$ y una expresión analítica dependiente de los parámetros de la política ($\theta$) y que se puede muestrear directamente a partir de la interacción con el ambiente a medida que se mejora la política.
# Esto en últimas permite encontrar la máxima dirección de crecimiento de $J(\theta)$ y ajustar los parámetros utilizando una constante de proporcionalidad $\alpha$ como se escribió en la Ecuación (1).
#
#  $\nabla J(\theta) \propto \sum_s \mu(s) \sum_a q_\pi(s, a) \nabla \pi(a|s, \theta)$ &emsp;&emsp;&emsp;$(2)$
#
# El algoritmo de REINFORCE, un algoritmo de gradiente de política, utiliza la regla de actualización de la Ecuación (3), estimando el gradiente estocástico utilizando el retorno $G_t$:
#
# $\theta_{t+1} \doteq \theta_t + \alpha G_t \frac{\nabla \pi(A_t | S_t, \theta_t)}{\pi(A_t | S_t, \theta_t)}$ &emsp;&emsp;&emsp;$(3)$
#
# En esta actualización, cada incremento es proporcional al producto del retorno $G_t$ y un vector: el gradiente de la probabilidad de escoger la acción tomada dividida por la probabilidad de escoger dicha acción. Este vector corresponde a la dirección en el espacio de parámetros en la cual crece mayormente la probabilidad de escoger la acción $A_t$ en futuras visitas al estado $S_t$. La actualización es proporcional al retorno $G_t$, favoreciendo las acciones que generan mayor recompensa a largo plazo, y es inversamente proporcional a la probabilidad de escoger la acción, no favoreciendo así incorrectamente a acciones que se eligen frecuentemente. Debido a que REINFORCE utiliza el retorno completo desde un tiempo $t$, que incluye todas las recompensas vistas hasta el final del episodio, se dice que entonces REINFORCE es también un método de Monte Carlo. [1]
#
# Finalmente, se consigue una variación de la regla de actualización de REINFORCE si se incluye un <i>baseline</i>, como muestra la Ecuación (4). Incluir un <i>baseline</i> no cambia el valor esperado de la actualización, pero sí puede tener un efecto significativo en la varianza del aprendizaje, reduciéndola significativamente y haciendo el entrenamiento más estable. Para el caso de un MDP, dicho <i>baseline</i> debería variar con el estado, por lo cual una selección típica es utilizar una función de valor de estado $\hat{v}(s,\text{w})$, donde $\text{w}$ es un vector de pesos aprendido por otro algoritmo de valor-acción. [1]
#
# $\theta_{t+1} \doteq \theta_t + \alpha (G_t-b(S_t)) \frac{\nabla \pi(A_t | S_t, \theta_t)}{\pi(A_t | S_t, \theta_t)}$ &emsp;&emsp;&emsp;$(4)$

# %% [markdown]
# # Instalación de Librerías
#
# En este tutorial se va a utilizar un juego de Atari 2600: <i>Atlantis</i>. Este videojuego hace parte de los ambientes de Atari de la librería Gymnasium. También se requiere instalar correctamente PyTorch para el uso de redes neuronales. Ejecute el siguiente bloque de código para instalar todas las librerías y herramientas necesarias.

# %%
#Descarga librerías no incluidas en Colab usando pip
#!pip3 uninstall --yes torch torchaudio torchvision torchtext torchdata #Para compatibilidad de PyTorch
# !pip3 install torch torchaudio torchvision torchtext torchdata #Instala PyTorch
# !pip install ale-py #ALE se utiliza para el ambiente de Atari
# !pip install "gymnasium[atari,accept-rom-license]" stable-baselines3 autorom renderlab -q #Gymnasium, envs de Atari y ROM
# !AutoROM --accept-license
# !pip install renderlab #usado para renderizar gym
# !pip install stable_baselines3 #Stable Baselines3 -> Framework de Reinforcement Learning

#Importa estas librerías
import torch #Importa herramientas de PyTorch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torch.distributions import Categorical
import gymnasium #importa la libreria de gymnasium con las simulaciones
import renderlab #importa renderlab para los videos
import stable_baselines3 #importa Stable Baselines3
from stable_baselines3.common.env_util import make_atari_env #importa make_atari_env para escala de grises
from stable_baselines3.common.vec_env import DummyVecEnv, VecFrameStack #importa VecFrameStack para apilar frames y acelerar así el entrenamiento
import ale_py #importa ale para los ambientes de Atari
from gymnasium.wrappers import TimeLimit #importa timelimit para acortar los episodios
from collections import deque #importa para ajustar los videos con VecFrameStack
import cv2 #importa para ajustar los videos con VecFrameStack

#!Importante:
gymnasium.register_envs(ale_py) #Hay que registrar los entornos de ALE manualmente!!!

#Importa otras librerías básicas
import numpy as np
import matplotlib.pyplot as plt
import random
import math
import pandas as pd
import sys
import argparse
from itertools import count

#Limpia los registros generados
from IPython.display import clear_output
clear_output()
print("Todas las librerías han sido instaladas correctamente.")
# Out:
# Todas las librerías han sido instaladas correctamente.

# %% [markdown]
# # Familiarización con el Entorno de Gym

# %% [markdown]
# En esta oportunidad, trabajaremos con el entorno de <i>Atlantis</i> [2]. En este juego de Atari, la ciudad submarina de Atlantis está siendo atacada por aviones y otras aeronaves; el jugador debe usar una serie de torretas para derribar estas aeronaves antes de que logren destruir por completo la ciudad.
# Una captura de cómo se ve el juego se muestra en la Figura 3.
#
#
# ![freeway](https://raw.githubusercontent.com/MAIA4361-Aprendizaje-refuerzo-profundo/Notebooks_Tareas/main/Images/atlantis.png)
#
# <center>Figura 1. Ejemplo de una partida de <i>Atlantis</i>.</center>
#
# En este ambiente el jugador tiene 4 posibles acciones en cada paso de tiempo:
#
# *   0 - No hace nada (NOOP).
# *   1 - Dispara la torreta central (FIRE).
# *   2 - Dispara la torreta de la derecha (RIGHTFIRE).
# *   3 - Dispara la torreta de la izquierda (LEFTFIRE).
#
# Normalmente, cuando el jugador logra asestar un disparo a una aeronave recibe 100 o 200 puntos. También el jugador comienza a recibir puntos después de cierto tiempo por sobrevivir. En este ambiente se puede también configurar el modo de juego (mode) con un número entre 0 y 3, modificando la cantidad de aeronaves y su velocidad, mientras que la única dificultad (difficulty) disponible 0.

# %% [markdown]
# ## Ejemplo
#
# En este ejemplo se muestra cómo simular una partida de <i>Atlantis</i> dentro de Google Colab. Para este ejemplo se usa el modo 0 de juego, y en cada paso de tiempo se hace una selección aleatoria entre las 4 acciones disponibles.

# %%
#Parámetros del ambiente
env_render = gymnasium.make("ALE/Atlantis-v5", render_mode="rgb_array", mode=0, difficulty=0) #Se crea el ambiente.
env_render = renderlab.RenderFrame(env_render, "./output") #Se crea una copia que se pueda renderizar con renderlab

terminated = False #Inicializa una condición para el loop
truncated = False #Inicializa una condición para el loop
total_reward=0 #Inicializa contador del retorno

obs , info = env_render.reset() #Se reinicia el estado para comenzar. En obs se almacena el estado observado
while not (terminated or truncated): #Simula hasta que termine la partida
  action = random.choice([0, 1, 2, 3])  # Elige una acción aleatoria
  obs, reward, terminated, truncated, info = env_render.step(action) #Da el paso
  total_reward += reward #Suma recompensa

print("Recompensa obtenida en el episodio:",total_reward) #Se imprime la recompensa obtenida
print("\n\n")

env_render.play() #Con esta función se obtiene el video de la simulación
# Out:
# Recompensa obtenida en el episodio: 15600.0
#
#
#
# Moviepy - Building video temp-{start}.mp4.
# Moviepy - Writing video temp-{start}.mp4
# Moviepy - Done !
# Moviepy - video ready temp-{start}.mp4
# <video controls  >
#  <source src="data:video/mp4;base64,..." type="video/mp4">
#  Your browser does not support the video tag.
#  </video>

# %% [markdown]
# En la simulación se puede observar que una política uniformemente aleatoria obtendrá, por lo general, una puntuación cercana a 10,000 puntos antes de perder. Con esta referencia se pueden comparar el resto de políticas que se obtengan en el tutorial utilizando el algoritmo de REINFORCE.

# %% [markdown]
# ## Ejercicio Práctico
#
# Antes de continuar, puede intentar simular una partida utilizando los modos de juego 1, 2 o 3, manteniendo la aleatoriedad de acciones para comprobar el correcto entendimiento del ambiente.

# %%
# Ejecute una partida con modo 1, 2 o 3

# =====================================================
# COMPLETAR ===========================================

# Se selecciona el modo 2 para observar un comportamiento distinto del juego
selected_mode = 2

# Se crea el ambiente con el nuevo modo y se envuelve para poder renderizar
env_render = gymnasium.make("ALE/Atlantis-v5", render_mode="rgb_array",
                            mode=selected_mode, difficulty=0)
env_render = renderlab.RenderFrame(env_render, "./output")

# Inicialización de banderas y contador de recompensa
terminated = False
truncated = False
total_reward = 0

# Se reinicia el ambiente y se obtiene la observación inicial
obs, info = env_render.reset()

# Bucle principal: se simula hasta que el episodio termine
while not (terminated or truncated):
    # Política uniforme aleatoria entre las 4 acciones disponibles
    action = random.choice([0, 1, 2, 3])
    obs, reward, terminated, truncated, info = env_render.step(action)
    total_reward += reward

# Se imprime la recompensa total y se renderiza el video
print(f"Modo de juego utilizado: {selected_mode}")
print("Recompensa obtenida en el episodio:", total_reward)
print("\n\n")
env_render.play()

# =====================================================
# Out:
# Modo de juego utilizado: 2
# Recompensa obtenida en el episodio: 10600.0
#
#
#
# Moviepy - Building video temp-{start}.mp4.
# Moviepy - Writing video temp-{start}.mp4
# t:  92%|█████████▏| 765/834 [00:01<00:00, 596.20it/s, now=None]WARNING:py.warnings:/usr/local/lib/python3.12/dist-packages/moviepy/video/io/ffmpeg_reader.py:123: UserWarning: Warning: in file ./output/1777690278.9537282.mp4, 100800 bytes wanted but 0 bytes read,at frame 833/834, at time 27.77/27.77 sec. Using the last valid frame instead.
#   warnings.warn("Warning: in file %s, "%(self.filename)+
# Moviepy - Done !
# Moviepy - video ready temp-{start}.mp4
# <video controls  >
#  <source src="data:video/mp4;base64,..." type="video/mp4">
#  Your browser does not support the video tag.
#  </video>

# %% [markdown]
# # REINFORCE
#
# En el siguiente bloque de código se suministra una implementación del algoritmo de REINFORCE basada en un ejemplo oficial encontrado en el repositorio de PyTorch [3], originalmente programado para resolver el ambiente de <i>Cart Pole</i>. En esta versión, se utiliza una red neuronal convolucional de 3 capas para aprender a partir de las imágenes del ambiente de Atari. Para agilizar el aprendizaje, dichas imágenes se reescalan a un tamaño de 84x84 y se colocan en escala de grises, y se aplica un framestack de 2 frames para captar información de movimiento. Es importante mencionar que en esta clase se pueden personalizar los siguientes hiperparámetros del algoritmo:
#
#
# *   `use_baseline`: Parámetro que puede tomar como valor un número entero entre 0 y 3. Este es el parámetro más importante para este tutorial, ya que cambia la configuración de <i>baseline</i> utilizado para el algoritmo. Un valor de 0 indica que no se usa ningún <i>baseline</i> (valor por defecto); un valor de 1 hace que se aplique una normalización de la recompensa y los retornos que reduce la varianza, aunque no es un <i>baseline</i> como tal, debería tener el mismo efecto; un valor de 2 usa como <i>baseline</i> el promedio de los retornos vistos anteriormente, lo cual es una métrica sencilla de calcular, pero es poco recomendada y puede no ser útil; y finalmente un valor de 3 utiliza una segunda red neuronal para estimar la función de valor en cada estado $V(s)$.
# *   `learning_rate_reinforce`: Tasa de aprendizaje del algoritmo de REINFORCE (por defecto en `1e-5`).
# *   `learning_rate_baseline`: Tasa de aprendizaje para la red neuronal que aproxima la función de valor, cuando se utiliza `use_baseline=3` (por defecto en `1e-6`)
# *   `gamma`: Factor de descuento (por defecto en `1`).
# *   `max_steps_per_episode`: Cantidad máxima de pasos que puede pasar el agente en un episodio, evitando la posibilidad de partidas infinitas (por defecto en `5000`).
# *   `max_training_episodes`: Cantidad máxima de episodios por los que puede entrenar el algoritmo (por defecto en `1500`).

# %%
"""
Adaptado del ejemplo de PyTorch encontrado en https://github.com/pytorch/examples/blob/main/reinforcement_learning/reinforce.py
"""

class Policy_atla(nn.Module):
  """Esta clase define la red neuronal usada para el juego de Atlantis"""
  def __init__(self):
    super(Policy_atla, self).__init__()
    #Crea una red convolucional de 3 capas.
    #Entrada: 2 frames en escala de grises de tamaño 84x84
    #Salida: Distribución de probabilidad sobre 4 acciones posibles
    self.conv1 = nn.Conv2d(2, 32, kernel_size=8, stride=4)
    self.bn1 = nn.BatchNorm2d(32)
    self.conv2 = nn.Conv2d(32, 64, kernel_size=4, stride=2)
    self.bn2 = nn.BatchNorm2d(64)
    self.conv3 = nn.Conv2d(64, 64, kernel_size=3, stride=1)
    self.bn3 = nn.BatchNorm2d(64)
    self.fc1 = nn.Linear(64 * 7 * 7, 512)
    self.fc2 = nn.Linear(512, 4)
    self.saved_log_probs = []
    self.rewards = []
  def forward(self, x):
    #Flujo de la red neuronal
    #Aplica una función SOFTMAX en la salida para retornar probabilidades
    x = F.relu(self.conv1(x))
    x = F.relu(self.conv2(x))
    x = F.relu(self.conv3(x))
    x = x.reshape(x.size(0), -1)
    x = F.relu(self.fc1(x))
    return F.softmax(self.fc2(x), dim=1)

class ValueNetwork(nn.Module):
  """Esta clase define la red neuronal usada para la estimación de la función de valor (baseline)"""
  def __init__(self):
    #Crea una red convolucional de 3 capas.
    #Entrada: 2 frames en escala de grises de tamaño 84x84
    #Salida: Éstimación de la función de valor en el estado
    super(ValueNetwork, self).__init__()
    self.conv1 = nn.Conv2d(2, 32, kernel_size=8, stride=4)
    self.conv2 = nn.Conv2d(32, 64, kernel_size=4, stride=2)
    self.conv3 = nn.Conv2d(64, 64, kernel_size=3, stride=1)
    self.fc1 = nn.Linear(64 * 7 * 7, 512)
    self.fc2 = nn.Linear(512, 1)
  def forward(self, x):
    #Flujo de la red neuronal
    #Retorna un solo valor escalar que representa el valor esperado del estado actual
    x = F.relu(self.conv1(x))
    x = F.relu(self.conv2(x))
    x = F.relu(self.conv3(x))
    x = x.reshape(x.size(0), -1)
    x = F.relu(self.fc1(x))
    return self.fc2(x).squeeze(-1)

class REINFORCE_atla:
  """Esta clase inicializa el agente, lo entrena y realiza una validación"""
  def __init__(self, use_baseline=0, learning_rate_reinforce=1e-5, learning_rate_baseline=1e-6, gamma=1, max_steps_per_episode=5000, max_training_episodes=1500):
    #INPUTS:
    #use_baseline: Indica si usar o no baseline y qué baseline usar
    #(0: No usar Baseline, 1: Usar normalización de recompensas, 2: Usar promedio de recompensas como baseline, 3: Usar función de valor como baseline)
    #learning_rate_reinforce: Tasa de aprendizaje del algoritmo de Reinforce
    #learning_rate_baseline: Tasa de aprendizaje para el estimador de la función de valor
    #gamma: factor de descuento
    #max_steps_per_episode: Máxima duración de un episodio
    #max_training_episodes: Cantidad máxima de episodios para entrenar

    #Algunos parámetros
    self.gamma=gamma
    self.seed=543
    self.log_interval=20 #Cada cuántos episodios se imprime un logger en pantalla
    self.max_steps_per_episode=max_steps_per_episode #Cantidad máxima de pasos por episodio (limitar duración)
    self.max_training_episodes=max_training_episodes #Cantidad máxima de episodios para entrenamiento (limitar duración)
    self.use_baseline=use_baseline #Usar o no baseline y de qué tipo (0, 1, 2 o 3)

    #Crea el ambiente con escala de grises y apilando 2 frames
    self.env = make_atari_env("ALE/Atlantis-v5",n_envs=1,seed=0,env_kwargs={"mode": 0, "difficulty": 0})
    self.env = VecFrameStack(self.env, n_stack=2)

    #Inicializa ambiente
    obs = self.env.reset()
    torch.manual_seed(self.seed)

    #Inicializa variables para almacenar estados/datos
    self.last_state = obs
    self.last_states = []
    self.all_episodes_rewards = []

    input_dim = obs.shape[0]
    if hasattr(self.env.action_space, 'n'):
      output_dim = self.env.action_space.n
    else:
      raise ValueError("El espacio de acciones debe ser discreto.")

    #Inicializa la política (red neuronal)
    self.policy = Policy_atla()
    self.optimizer = optim.Adam(self.policy.parameters(), lr=learning_rate_reinforce)  # learning_Rate más bajo suele funcionar mejor en imágenes
    self.eps = np.finfo(np.float32).eps.item()

    #Inicializa el estimador de la función de valor (red neuronal, si se usa use_baseline=3)
    self.value_function_estimator = ValueNetwork()
    self.value_function_estimator_optimizer = optim.Adam(self.value_function_estimator.parameters(), lr=learning_rate_baseline)


  def select_action(self, state, epsilon=0.15):
    #Esta función selecciona una acción en cada paso de la simulación
    #INPUTS:
    #state: el estado correspondiente a la observación del ambiente (framestack de 2 frames)
    #epsilon: una tasa de exploración adicional

    #Convierte la imagen en un tensor de PyTorch. Dimension original: (1, 84, 84, 2)
    state = torch.from_numpy(state).float()
    state = state.permute(0, 3, 1, 2)  #Dimension final: (1, 2, 84, 84)

    if random.random() < epsilon:  # Con probabilidad epsilon, se elige acción aleatoria
      action = random.choice([0, 1, 2, 3])
    else:
      #La red neuronal elige una acción
      probs = self.policy(state)
      m = Categorical(probs)
      action = m.sample()
      self.policy.saved_log_probs.append(m.log_prob(action))
      action = action.item()

    #Guarda estados para uso de baseline
    self.last_state = state
    self.last_states.append(state)

    return action #Retorna la acción escogida (0, 1, 2 o 3)


  def finish_episode(self):
    #Al final de cada episodio hace una actualización de la política (Monte Carlo)

    #Inicializa valores
    R = 0
    policy_loss = []
    returns = deque()

    #Obtiene el retorno con todas las recompensas del episodio teniendo en cuenta el factor de descuento
    for r in self.policy.rewards[::-1]:
        R = r + self.gamma * R
        returns.appendleft(R)
    returns = np.array(returns)
    returns = torch.tensor(returns)

    #Caso de Baseline
    if(self.use_baseline==3): #Si use_baseline==3, usa la aproximación de función de valor
      state_batch = torch.cat(self.last_states, dim=0)
      value_preds = self.value_function_estimator(state_batch).squeeze().detach()
      advantages = returns - value_preds
    elif(self.use_baseline==2): #Si use_baseline==2, usa un promedio de los retornos vistos
      advantages = returns - returns.mean()
    elif(self.use_baseline==1): #Si use_baseline==1, sólo aplica una normalización del retorno
      if len(returns) > 1 and returns.std() > 1e-6:
        returns = (returns - returns.mean()) / (returns.std() + self.eps)
      else:
        returns = returns - returns.mean()
      advantages = returns
    else: #En cualquier otro caso (#Si use_baseline==0), no usa baseline
      advantages = returns

    #Cálculo de pérdida de la política
    for log_prob, advantage in zip(self.policy.saved_log_probs, advantages):
        if log_prob is not None:
            policy_loss.append(-log_prob * advantage)

    #Retropropagación de la red neuronal
    self.optimizer.zero_grad()
    if len(policy_loss) == 0:
        return
    policy_loss = torch.cat(policy_loss).sum()
    policy_loss.backward()
    self.optimizer.step()

    #Si use_baseline==3, también actualiza la red neuronal que estima la función de valor
    if(self.use_baseline==3):
      self.value_function_estimator_optimizer.zero_grad()
      predicted_values = self.value_function_estimator(state_batch).squeeze()
      value_function_estimator_loss = F.mse_loss(predicted_values, returns)
      value_function_estimator_loss.backward()
      self.value_function_estimator_optimizer.step()
      self.last_states.clear()

    #Limpia las variables temporales
    del self.policy.rewards[:]
    del self.policy.saved_log_probs[:]


  def train(self):
    #Esta función ejecuta todo el entrenamiento

    #Inicializa variables
    running_reward = 0
    cumulative_episodes_reward=0

    for i_episode in range(1,self.max_training_episodes+1): #Ejecuta como máximo max_steps_per_episode para que el entrenamiento no sea infinito
        #Inicializa el ambiente y la recompensa total del episodio
        state = self.env.reset()
        ep_reward = 0
        for t in range(1, self.max_steps_per_episode):  #Cada episodio tiene un máximo de pasos para que no pueda quedarse hasta el infinito
          action = self.select_action(state, epsilon=0) #Elige acción
          state, reward, done, _ = self.env.step([action])
          self.policy.rewards.append(reward[0]) #Almacena recompensa para actualizaciones
          ep_reward += np.array(reward).item()
          if done: #Si pierde, termina el episodio
            break

        #Después de terminar el episodio, calcula running_reward, y actualiza variables para el promedio y grafica
        running_reward = 0.05 * ep_reward + (1 - 0.05) * running_reward
        cumulative_episodes_reward += ep_reward

        self.finish_episode()

        #Imprime estadísticas en pantalla
        if i_episode % self.log_interval == 0:
          print('Episode {} completed.\tLast Reward: {:.2f}\tLast 20 Episodes Average Reward: {:.2f}\t\tRunning reward: {:.2f}'.format(
                  i_episode, ep_reward*100, cumulative_episodes_reward*100/20, running_reward*100)) #Las recompensas están divididas por 100 en el ambiente
          self.all_episodes_rewards.append(cumulative_episodes_reward*100/20)
          cumulative_episodes_reward=0
        #Cuando running_reward pasa un umbral da por terminado el entrenamiento
        if running_reward > 5:
          print("Solved! Running reward is now {} and "
                  "the last episode runs to {} time steps!".format(running_reward*100, t))
          break

  def graph_training(self):
    # Esta función realiza una gráfica de la recompensa cada 20 episodios
    interval = 20  # Intervalo entre muestras
    episodes = [i * interval for i in range(1, len(self.all_episodes_rewards) + 1)]

    plt.figure(figsize=(10, 5))
    plt.plot(episodes, self.all_episodes_rewards, color='orange', marker='o')
    plt.xlabel('Episodio')
    plt.ylabel('Recompensa total')
    plt.title('Curva de aprendizaje: Recompensa promedio de cada 20 episodios')
    plt.grid(True)
    plt.tight_layout()
    plt.show()

  def video(self):
    #Crea un entorno para renderizar
    env = gymnasium.make("ALE/Atlantis-v5", render_mode="rgb_array", mode=0, difficulty=0)
    env = renderlab.RenderFrame(env, "./output")

    #Frame stack manual para el modelo, para que el video no salga cortado (se apilan dos frame, en escala de gris, tamano 84x84)
    frame_stack = deque(maxlen=2)

    #Reset inicial
    obs, info = env.reset()

    #Procesa una copia del frame solo para el modelo
    def preprocess(obs):
      gray = obs.mean(axis=2).astype(np.uint8)  # escala de grises
      resized = cv2.resize(gray, (84, 84), interpolation=cv2.INTER_AREA) #redimensiona
      return resized

    #Realiza el framestack
    preprocessed = preprocess(obs)
    for _ in range(2):
      frame_stack.append(preprocessed)

    #Inicialización del ambiente
    terminated = False
    truncated = False
    total_reward = 0

    #Loop de simulacion
    while not (terminated or truncated):
        #Convierte frames a la forma (2, 84, 84)
        stacked_obs = np.stack(frame_stack, axis=0)

        #Cambia el orden de las dimensiones a (1, 2, 84, 84) (batch_size, channels, height, width)
        stacked_obs = np.expand_dims(stacked_obs, axis=0)  # (1, 2, 84, 84)
        stacked_obs = np.transpose(stacked_obs, (0, 2, 3, 1))  # (1, 84, 84, 2)

        #Elige la accion
        action=self.select_action(stacked_obs, epsilon=0) #especifica que no hay exploracion

        #Avanza en el entorno real manteniendo la continuidad en el video
        obs, reward, terminated, truncated, info = env.step(action)
        total_reward += reward

        #Actualiza el stack solo para el modelo
        preprocessed = preprocess(obs)
        frame_stack.append(preprocessed)

    #Muestra la recompensa total obtenida y el video
    print("\n\n")
    print("Recompensa obtenida en el episodio:", total_reward)
    env.play()

# %% [markdown]
# ## Ejemplo de Uso
#
# Para utilizar ese código, simplemente debe:
#
# 1.   Crear el agente.
# 2.   Entrenar el algoritmo.
# 3.   Mostrar la curva de aprendizaje (opcional).
# 4.   Mostrar el video de validación de la política aprendida.
# 5.   Guardar la política como archivo (recomendado, descargar de los archivos Colab).
#
# A continuación, se muestra un ejemplo de uso para el caso `use_baseline=0`, es decir, un entrenamiento sin usar <i>baselines</i>. Puede reutilizar este bloque de código para los ejercicios posteriores.

# %%
# Ejemplo: Entrenamiento de REINFORCE sin baselines
print("Entrenamiento SIN baseline.")
print("\n")
agente_atlantis0=REINFORCE_atla(use_baseline=0,max_steps_per_episode=5000, max_training_episodes=1500) #Inicializa agente
agente_atlantis0.train() #Entrena
agente_atlantis0.graph_training() #Grafica curva de aprendizaje
agente_atlantis0.video() #Validación en video
torch.save(agente_atlantis0.policy.state_dict(), 'policy_agente0.pth') #Salva la politica
# Out:
# Entrenamiento SIN baseline.
# WARNING:py.warnings:/usr/local/lib/python3.12/dist-packages/jupyter_client/session.py:203: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   return datetime.utcnow().replace(tzinfo=utc)
# Episode 20 completed.	Last Reward: 100.00	Last 20 Episodes Average Reward: 75.00		Running reward: 45.04
# Episode 40 completed.	Last Reward: 200.00	Last 20 Episodes Average Reward: 80.00		Running reward: 68.65
# Episode 60 completed.	Last Reward: 0.00	Last 20 Episodes Average Reward: 90.00		Running reward: 81.07
# Episode 80 completed.	Last Reward: 0.00	Last 20 Episodes Average Reward: 130.00		Running reward: 99.91
# Episode 100 completed.	Last Reward: 200.00	Last 20 Episodes Average Reward: 265.00		Running reward: 197.39
# Episode 120 completed.	Last Reward: 300.00	Last 20 Episodes Average Reward: 95.00		Running reward: 133.33
# Episode 140 completed.	Last Reward: 300.00	Last 20 Episodes Average Reward: 280.00		Running reward: 225.95
# Episode 160 completed.	Last Reward: 800.00	Last 20 Episodes Average Reward: 205.00		Running reward: 212.49
# Episode 180 completed.	Last Reward: 0.00	Last 20 Episodes Average Reward: 285.00		Running reward: 255.67
# Episode 200 completed.	Last Reward: 0.00	Last 20 Episodes Average Reward: 240.00		Running reward: 248.53
# Episode 220 completed.	Last Reward: 900.00	Last 20 Episodes Average Reward: 250.00		Running reward: 271.49
# Episode 240 completed.	Last Reward: 200.00	Last 20 Episodes Average Reward: 250.00		Running reward: 258.43
# Episode 260 completed.	Last Reward: 600.00	Last 20 Episodes Average Reward: 315.00		Running reward: 305.60
# Episode 280 completed.	Last Reward: 0.00	Last 20 Episodes Average Reward: 150.00		Running reward: 208.97
# Episode 300 completed.	Last Reward: 0.00	Last 20 Episodes Average Reward: 145.00		Running reward: 176.37
# Episode 320 completed.	Last Reward: 200.00	Last 20 Episodes Average Reward: 140.00		Running reward: 148.48
# Episode 340 completed.	Last Reward: 300.00	Last 20 Episodes Average Reward: 120.00		Running reward: 128.76
# Episode 360 completed.	Last Reward: 0.00	Last 20 Episodes Average Reward: 145.00		Running reward: 153.80
# Episode 380 completed.	Last Reward: 800.00	Last 20 Episodes Average Reward: 205.00		Running reward: 186.53
# Episode 400 completed.	Last Reward: 300.00	Last 20 Episodes Average Reward: 350.00		Running reward: 278.65
# Episode 420 completed.	Last Reward: 0.00	Last 20 Episodes Average Reward: 60.00		Running reward: 139.96
# Episode 440 completed.	Last Reward: 0.00	Last 20 Episodes Average Reward: 140.00		Running reward: 138.21
# Episode 460 completed.	Last Reward: 100.00	Last 20 Episodes Average Reward: 210.00		Running reward: 171.16
# Episode 480 completed.	Last Reward: 500.00	Last 20 Episodes Average Reward: 165.00		Running reward: 177.70
# Episode 500 completed.	Last Reward: 100.00	Last 20 Episodes Average Reward: 160.00		Running reward: 175.62
# Episode 520 completed.	Last Reward: 600.00	Last 20 Episodes Average Reward: 240.00		Running reward: 230.18
# Episode 540 completed.	Last Reward: 500.00	Last 20 Episodes Average Reward: 270.00		Running reward: 279.59
# Episode 560 completed.	Last Reward: 200.00	Last 20 Episodes Average Reward: 165.00		Running reward: 205.68
# Episode 580 completed.	Last Reward: 0.00	Last 20 Episodes Average Reward: 200.00		Running reward: 200.98
# Episode 600 completed.	Last Reward: 0.00	Last 20 Episodes Average Reward: 285.00		Running reward: 238.14
# Episode 620 completed.	Last Reward: 300.00	Last 20 Episodes Average Reward: 210.00		Running reward: 215.73
# Episode 640 completed.	Last Reward: 600.00	Last 20 Episodes Average Reward: 210.00		Running reward: 216.75
# Episode 660 completed.	Last Reward: 0.00	Last 20 Episodes Average Reward: 95.00		Running reward: 139.38
# Episode 680 completed.	Last Reward: 200.00	Last 20 Episodes Average Reward: 165.00		Running reward: 156.27
# Episode 700 completed.	Last Reward: 700.00	Last 20 Episodes Average Reward: 205.00		Running reward: 200.62
# Episode 720 completed.	Last Reward: 0.00	Last 20 Episodes Average Reward: 255.00		Running reward: 239.21
# Episode 740 completed.	Last Reward: 0.00	Last 20 Episodes Average Reward: 180.00		Running reward: 195.28
# Episode 760 completed.	Last Reward: 100.00	Last 20 Episodes Average Reward: 150.00		Running reward: 165.02
# Episode 780 completed.	Last Reward: 0.00	Last 20 Episodes Average Reward: 115.00		Running reward: 134.03
# Episode 800 completed.	Last Reward: 200.00	Last 20 Episodes Average Reward: 165.00		Running reward: 148.53
# Episode 820 completed.	Last Reward: 100.00	Last 20 Episodes Average Reward: 220.00		Running reward: 198.62
# Episode 840 completed.	Last Reward: 100.00	Last 20 Episodes Average Reward: 150.00		Running reward: 158.89
# Episode 860 completed.	Last Reward: 100.00	Last 20 Episodes Average Reward: 175.00		Running reward: 159.40
# Episode 880 completed.	Last Reward: 0.00	Last 20 Episodes Average Reward: 100.00		Running reward: 121.77
# Episode 900 completed.	Last Reward: 400.00	Last 20 Episodes Average Reward: 290.00		Running reward: 211.91
# Episode 920 completed.	Last Reward: 100.00	Last 20 Episodes Average Reward: 150.00		Running reward: 166.05
# Episode 940 completed.	Last Reward: 0.00	Last 20 Episodes Average Reward: 180.00		Running reward: 167.17
# Episode 960 completed.	Last Reward: 100.00	Last 20 Episodes Average Reward: 155.00		Running reward: 171.74
# Episode 980 completed.	Last Reward: 0.00	Last 20 Episodes Average Reward: 160.00		Running reward: 159.99
# Episode 1000 completed.	Last Reward: 600.00	Last 20 Episodes Average Reward: 235.00		Running reward: 212.46
# Episode 1020 completed.	Last Reward: 700.00	Last 20 Episodes Average Reward: 260.00		Running reward: 239.63
# Episode 1040 completed.	Last Reward: 100.00	Last 20 Episodes Average Reward: 225.00		Running reward: 227.30
# Episode 1060 completed.	Last Reward: 100.00	Last 20 Episodes Average Reward: 245.00		Running reward: 230.07
# Episode 1080 completed.	Last Reward: 0.00	Last 20 Episodes Average Reward: 170.00		Running reward: 190.45
# Episode 1100 completed.	Last Reward: 0.00	Last 20 Episodes Average Reward: 385.00		Running reward: 327.32
# Episode 1120 completed.	Last Reward: 400.00	Last 20 Episodes Average Reward: 190.00		Running reward: 235.31
# Episode 1140 completed.	Last Reward: 300.00	Last 20 Episodes Average Reward: 165.00		Running reward: 202.42
# Episode 1160 completed.	Last Reward: 100.00	Last 20 Episodes Average Reward: 285.00		Running reward: 235.37
# Episode 1180 completed.	Last Reward: 0.00	Last 20 Episodes Average Reward: 285.00		Running reward: 263.22
# Episode 1200 completed.	Last Reward: 800.00	Last 20 Episodes Average Reward: 170.00		Running reward: 213.14
# Episode 1220 completed.	Last Reward: 0.00	Last 20 Episodes Average Reward: 105.00		Running reward: 143.40
# Episode 1240 completed.	Last Reward: 100.00	Last 20 Episodes Average Reward: 125.00		Running reward: 136.99
# Episode 1260 completed.	Last Reward: 500.00	Last 20 Episodes Average Reward: 245.00		Running reward: 209.28
# Episode 1280 completed.	Last Reward: 0.00	Last 20 Episodes Average Reward: 120.00		Running reward: 145.44
# Episode 1300 completed.	Last Reward: 200.00	Last 20 Episodes Average Reward: 285.00		Running reward: 229.09
# Episode 1320 completed.	Last Reward: 100.00	Last 20 Episodes Average Reward: 190.00		Running reward: 211.61
# Episode 1340 completed.	Last Reward: 300.00	Last 20 Episodes Average Reward: 240.00		Running reward: 225.69
# Episode 1360 completed.	Last Reward: 100.00	Last 20 Episodes Average Reward: 185.00		Running reward: 180.29
# Episode 1380 completed.	Last Reward: 200.00	Last 20 Episodes Average Reward: 120.00		Running reward: 143.58
# Episode 1400 completed.	Last Reward: 0.00	Last 20 Episodes Average Reward: 90.00		Running reward: 107.14
# Episode 1420 completed.	Last Reward: 0.00	Last 20 Episodes Average Reward: 195.00		Running reward: 168.19
# Episode 1440 completed.	Last Reward: 300.00	Last 20 Episodes Average Reward: 175.00		Running reward: 168.30
# Episode 1460 completed.	Last Reward: 200.00	Last 20 Episodes Average Reward: 270.00		Running reward: 216.03
# Episode 1480 completed.	Last Reward: 0.00	Last 20 Episodes Average Reward: 90.00		Running reward: 131.90
# Episode 1500 completed.	Last Reward: 0.00	Last 20 Episodes Average Reward: 190.00		Running reward: 171.33
# Recompensa obtenida en el episodio: 17700.0
# Moviepy - Building video temp-{start}.mp4.
# Moviepy - Writing video temp-{start}.mp4
# Moviepy - Done !
# Moviepy - video ready temp-{start}.mp4
# <video controls  >
#  <source src="data:video/mp4;base64,..." type="video/mp4">
#  Your browser does not support the video tag.
#  </video>

# %% [markdown]
# ## Ejercicio Práctico
#
# En el anterior ejemplo se puede observar una recompensa en el video cercana a 12,000 puntos. Este puntaje es objetivamente bajo si se compara con el puntaje de 10,000 obtenido utilizando una política aleatoria. Esto muestra cómo entrenar sin <i>baselines</i> puede no ser efectivo, y en este ejercicio se busca explorar las otras alternativas, comparar los resultados obtenidos y reflexionar sobre los mismos. Se propone:
#
#
# *   Realice el mismo entrenamiento utilizando normalización de recompensas (`use_baseline=1`).
# *   Realice el mismo entrenamiento utilizando un promedio de los retornos obtenidos como <i>baseline</i> (`use_baseline=2`).
# *   Realice el mismo entrenamiento utilizando una segunda red neuronal para estimar la función de valor de los estados (`use_baseline=3`).
#
# Cada uno de estos entrenamientos debería tomar aproximadamente 10 minutos. Se recomienda salvar los entrenamientos realizados y vigilar que no se sature la RAM de Google Colab.
#
# Adicionalmente, puede probar modificando los parámetros de tasa de aprendizaje, a los cuales el algoritmo de REINFORCE es más sensible:
#
# *   `learning_rate_reinforce` entre `1e-3` y `1e-6`.
# *   `learning_rate_baseline` entre `1e-4` y `1e-6`.

# %%
# Entrenamiento de REINFORCE sin baselines pero con noramlizacion de recompensas (use_baseline=1)

# =====================================================
# COMPLETAR ===========================================

print("Entrenamiento CON normalización de retornos (use_baseline=1).")
print("\n")

# Se inicializa el agente con normalización de recompensas
# Se conservan los hiperparámetros por defecto sugeridos en el enunciado
agente_atlantis1 = REINFORCE_atla(
    use_baseline=1,
    learning_rate_reinforce=1e-5,
    gamma=1,
    max_steps_per_episode=5000,
    max_training_episodes=1500
)

# Entrenamiento del agente
agente_atlantis1.train()

# Curva de aprendizaje (recompensa promedio cada 20 episodios)
agente_atlantis1.graph_training()

# Validación visual de la política aprendida
agente_atlantis1.video()

# Se guarda la política entrenada para no perder el progreso
torch.save(agente_atlantis1.policy.state_dict(), 'policy_agente1.pth')

# =====================================================
# Out:
# Entrenamiento CON normalización de retornos (use_baseline=1).
#
#
# Episode 20 completed.	Last Reward: 100.00	Last 20 Episodes Average Reward: 100.00		Running reward: 62.69
# Episode 40 completed.	Last Reward: 0.00	Last 20 Episodes Average Reward: 105.00		Running reward: 90.77
# Episode 60 completed.	Last Reward: 300.00	Last 20 Episodes Average Reward: 80.00		Running reward: 86.36
# Episode 80 completed.	Last Reward: 200.00	Last 20 Episodes Average Reward: 105.00		Running reward: 102.20
# Episode 100 completed.	Last Reward: 100.00	Last 20 Episodes Average Reward: 160.00		Running reward: 152.67
# Episode 120 completed.	Last Reward: 0.00	Last 20 Episodes Average Reward: 115.00		Running reward: 117.37
# Episode 140 completed.	Last Reward: 300.00	Last 20 Episodes Average Reward: 50.00		Running reward: 80.34
# Episode 160 completed.	Last Reward: 100.00	Last 20 Episodes Average Reward: 125.00		Running reward: 108.17
# Episode 180 completed.	Last Reward: 0.00	Last 20 Episodes Average Reward: 90.00		Running reward: 104.80
# Episode 200 completed.	Last Reward: 0.00	Last 20 Episodes Average Reward: 205.00		Running reward: 159.79
# Episode 220 completed.	Last Reward: 0.00	Last 20 Episodes Average Reward: 110.00		Running reward: 118.50
# Episode 240 completed.	Last Reward: 800.00	Last 20 Episodes Average Reward: 135.00		Running reward: 144.54
# Episode 260 completed.	Last Reward: 700.00	Last 20 Episodes Average Reward: 140.00		Running reward: 152.31
# Episode 280 completed.	Last Reward: 100.00	Last 20 Episodes Average Reward: 130.00		Running reward: 129.63
# Episode 300 completed.	Last Reward: 100.00	Last 20 Episodes Average Reward: 120.00		Running reward: 128.25
# Episode 320 completed.	Last Reward: 200.00	Last 20 Episodes Average Reward: 195.00		Running reward: 178.97
# Episode 340 completed.	Last Reward: 0.00	Last 20 Episodes Average Reward: 130.00		Running reward: 146.75
# Episode 360 completed.	Last Reward: 0.00	Last 20 Episodes Average Reward: 175.00		Running reward: 161.67
# Episode 380 completed.	Last Reward: 0.00	Last 20 Episodes Average Reward: 200.00		Running reward: 184.87
# Episode 400 completed.	Last Reward: 0.00	Last 20 Episodes Average Reward: 220.00		Running reward: 198.18
# Episode 420 completed.	Last Reward: 100.00	Last 20 Episodes Average Reward: 130.00		Running reward: 140.88
# Episode 440 completed.	Last Reward: 0.00	Last 20 Episodes Average Reward: 85.00		Running reward: 105.26
# Episode 460 completed.	Last Reward: 800.00	Last 20 Episodes Average Reward: 140.00		Running reward: 136.25
# Episode 480 completed.	Last Reward: 300.00	Last 20 Episodes Average Reward: 120.00		Running reward: 130.79
# Episode 500 completed.	Last Reward: 200.00	Last 20 Episodes Average Reward: 135.00		Running reward: 136.40
# Episode 520 completed.	Last Reward: 100.00	Last 20 Episodes Average Reward: 100.00		Running reward: 112.54
# Episode 540 completed.	Last Reward: 100.00	Last 20 Episodes Average Reward: 160.00		Running reward: 146.51
# Episode 560 completed.	Last Reward: 0.00	Last 20 Episodes Average Reward: 100.00		Running reward: 116.33
# Episode 580 completed.	Last Reward: 0.00	Last 20 Episodes Average Reward: 165.00		Running reward: 149.28
# Episode 600 completed.	Last Reward: 1300.00	Last 20 Episodes Average Reward: 210.00		Running reward: 210.22
# Episode 620 completed.	Last Reward: 0.00	Last 20 Episodes Average Reward: 210.00		Running reward: 202.34
# Episode 640 completed.	Last Reward: 700.00	Last 20 Episodes Average Reward: 230.00		Running reward: 220.47
# Episode 660 completed.	Last Reward: 0.00	Last 20 Episodes Average Reward: 135.00		Running reward: 170.09
# Episode 680 completed.	Last Reward: 100.00	Last 20 Episodes Average Reward: 175.00		Running reward: 170.64
# Episode 700 completed.	Last Reward: 0.00	Last 20 Episodes Average Reward: 175.00		Running reward: 172.48
# Episode 720 completed.	Last Reward: 0.00	Last 20 Episodes Average Reward: 230.00		Running reward: 196.29
# Episode 740 completed.	Last Reward: 0.00	Last 20 Episodes Average Reward: 135.00		Running reward: 151.32
# Episode 760 completed.	Last Reward: 0.00	Last 20 Episodes Average Reward: 115.00		Running reward: 126.32
# Episode 780 completed.	Last Reward: 0.00	Last 20 Episodes Average Reward: 160.00		Running reward: 149.02
# Episode 800 completed.	Last Reward: 300.00	Last 20 Episodes Average Reward: 155.00		Running reward: 170.83
# Episode 820 completed.	Last Reward: 0.00	Last 20 Episodes Average Reward: 110.00		Running reward: 121.55
# Episode 840 completed.	Last Reward: 100.00	Last 20 Episodes Average Reward: 135.00		Running reward: 127.42
# Episode 860 completed.	Last Reward: 300.00	Last 20 Episodes Average Reward: 280.00		Running reward: 241.30
# Episode 880 completed.	Last Reward: 0.00	Last 20 Episodes Average Reward: 125.00		Running reward: 161.60
# Episode 900 completed.	Last Reward: 400.00	Last 20 Episodes Average Reward: 185.00		Running reward: 172.11
# Episode 920 completed.	Last Reward: 200.00	Last 20 Episodes Average Reward: 215.00		Running reward: 192.32
# Episode 940 completed.	Last Reward: 300.00	Last 20 Episodes Average Reward: 220.00		Running reward: 203.22
# Episode 960 completed.	Last Reward: 0.00	Last 20 Episodes Average Reward: 185.00		Running reward: 196.11
# Episode 980 completed.	Last Reward: 100.00	Last 20 Episodes Average Reward: 310.00		Running reward: 283.57
# Episode 1000 completed.	Last Reward: 100.00	Last 20 Episodes Average Reward: 245.00		Running reward: 264.40
# Episode 1020 completed.	Last Reward: 0.00	Last 20 Episodes Average Reward: 145.00		Running reward: 182.67
# Episode 1040 completed.	Last Reward: 500.00	Last 20 Episodes Average Reward: 290.00		Running reward: 253.79
# Episode 1060 completed.	Last Reward: 800.00	Last 20 Episodes Average Reward: 300.00		Running reward: 307.13
# Episode 1080 completed.	Last Reward: 200.00	Last 20 Episodes Average Reward: 165.00		Running reward: 209.65
# Episode 1100 completed.	Last Reward: 400.00	Last 20 Episodes Average Reward: 140.00		Running reward: 171.25
# Episode 1120 completed.	Last Reward: 100.00	Last 20 Episodes Average Reward: 215.00		Running reward: 200.34
# Episode 1140 completed.	Last Reward: 900.00	Last 20 Episodes Average Reward: 260.00		Running reward: 236.61
# Episode 1160 completed.	Last Reward: 200.00	Last 20 Episodes Average Reward: 145.00		Running reward: 173.94
# Episode 1180 completed.	Last Reward: 0.00	Last 20 Episodes Average Reward: 145.00		Running reward: 140.72
# Episode 1200 completed.	Last Reward: 0.00	Last 20 Episodes Average Reward: 70.00		Running reward: 94.65
# Episode 1220 completed.	Last Reward: 0.00	Last 20 Episodes Average Reward: 150.00		Running reward: 135.88
# Episode 1240 completed.	Last Reward: 800.00	Last 20 Episodes Average Reward: 170.00		Running reward: 174.72
# Episode 1260 completed.	Last Reward: 100.00	Last 20 Episodes Average Reward: 185.00		Running reward: 179.36
# Episode 1280 completed.	Last Reward: 0.00	Last 20 Episodes Average Reward: 155.00		Running reward: 156.08
# Episode 1300 completed.	Last Reward: 300.00	Last 20 Episodes Average Reward: 205.00		Running reward: 201.73
# Episode 1320 completed.	Last Reward: 0.00	Last 20 Episodes Average Reward: 185.00		Running reward: 191.47
# Episode 1340 completed.	Last Reward: 200.00	Last 20 Episodes Average Reward: 265.00		Running reward: 238.87
# Episode 1360 completed.	Last Reward: 300.00	Last 20 Episodes Average Reward: 175.00		Running reward: 199.03
# Episode 1380 completed.	Last Reward: 100.00	Last 20 Episodes Average Reward: 255.00		Running reward: 256.16
# Episode 1400 completed.	Last Reward: 0.00	Last 20 Episodes Average Reward: 250.00		Running reward: 247.91
# Episode 1420 completed.	Last Reward: 0.00	Last 20 Episodes Average Reward: 215.00		Running reward: 216.37
# Episode 1440 completed.	Last Reward: 0.00	Last 20 Episodes Average Reward: 170.00		Running reward: 181.21
# Episode 1460 completed.	Last Reward: 300.00	Last 20 Episodes Average Reward: 165.00		Running reward: 163.93
# Episode 1480 completed.	Last Reward: 0.00	Last 20 Episodes Average Reward: 85.00		Running reward: 111.75
# Episode 1500 completed.	Last Reward: 300.00	Last 20 Episodes Average Reward: 175.00		Running reward: 163.42
# Recompensa obtenida en el episodio: 43500.0
# Moviepy - Building video temp-{start}.mp4.
# Moviepy - Writing video temp-{start}.mp4
# t: 100%|█████████▉| 2198/2205 [00:02<00:00, 852.74it/s, now=None]WARNING:py.warnings:/usr/local/lib/python3.12/dist-packages/moviepy/video/io/ffmpeg_reader.py:123: UserWarning: Warning: in file ./output/1777691228.7187624.mp4, 100800 bytes wanted but 0 bytes read,at frame 2204/2205, at time 73.47/73.47 sec. Using the last valid frame instead.
#   warnings.warn("Warning: in file %s, "%(self.filename)+
# Moviepy - Done !
# Moviepy - video ready temp-{start}.mp4
# <video controls  >
#  <source src="data:video/mp4;base64,..." type="video/mp4">
#  Your browser does not support the video tag.
#  </video>

# %%
# Entrenamiento de REINFORCE con baseline como el promedio de los retornos (use_baseline=2)

# =====================================================
# COMPLETAR ===========================================

print("Entrenamiento CON baseline = promedio de retornos (use_baseline=2).")
print("\n")

# Se inicializa el agente usando como baseline el promedio de los retornos vistos
agente_atlantis2 = REINFORCE_atla(
    use_baseline=2,
    learning_rate_reinforce=1e-5,
    gamma=1,
    max_steps_per_episode=5000,
    max_training_episodes=1500
)

# Entrenamiento del agente
agente_atlantis2.train()

# Curva de aprendizaje (recompensa promedio cada 20 episodios)
agente_atlantis2.graph_training()

# Validación visual de la política aprendida
agente_atlantis2.video()

# Se guarda la política entrenada
torch.save(agente_atlantis2.policy.state_dict(), 'policy_agente2.pth')

# =====================================================
# Out:
# Entrenamiento CON baseline = promedio de retornos (use_baseline=2).
#
#
# Episode 20 completed.	Last Reward: 0.00	Last 20 Episodes Average Reward: 85.00		Running reward: 52.11
# Episode 40 completed.	Last Reward: 0.00	Last 20 Episodes Average Reward: 100.00		Running reward: 79.53
# Episode 60 completed.	Last Reward: 200.00	Last 20 Episodes Average Reward: 130.00		Running reward: 105.61
# Episode 80 completed.	Last Reward: 100.00	Last 20 Episodes Average Reward: 220.00		Running reward: 164.15
# Episode 100 completed.	Last Reward: 0.00	Last 20 Episodes Average Reward: 85.00		Running reward: 113.11
# Episode 120 completed.	Last Reward: 900.00	Last 20 Episodes Average Reward: 95.00		Running reward: 118.98
# Episode 140 completed.	Last Reward: 0.00	Last 20 Episodes Average Reward: 60.00		Running reward: 83.28
# Episode 160 completed.	Last Reward: 100.00	Last 20 Episodes Average Reward: 65.00		Running reward: 71.20
# Episode 180 completed.	Last Reward: 100.00	Last 20 Episodes Average Reward: 85.00		Running reward: 74.16
# Episode 200 completed.	Last Reward: 0.00	Last 20 Episodes Average Reward: 95.00		Running reward: 82.30
# Episode 220 completed.	Last Reward: 0.00	Last 20 Episodes Average Reward: 120.00		Running reward: 100.44
# Episode 240 completed.	Last Reward: 0.00	Last 20 Episodes Average Reward: 115.00		Running reward: 102.70
# Episode 260 completed.	Last Reward: 200.00	Last 20 Episodes Average Reward: 105.00		Running reward: 104.36
# Episode 280 completed.	Last Reward: 300.00	Last 20 Episodes Average Reward: 100.00		Running reward: 110.82
# Episode 300 completed.	Last Reward: 200.00	Last 20 Episodes Average Reward: 150.00		Running reward: 140.66
# Episode 320 completed.	Last Reward: 200.00	Last 20 Episodes Average Reward: 250.00		Running reward: 205.30
# Episode 340 completed.	Last Reward: 0.00	Last 20 Episodes Average Reward: 140.00		Running reward: 153.09
# Episode 360 completed.	Last Reward: 200.00	Last 20 Episodes Average Reward: 60.00		Running reward: 96.76
# Episode 380 completed.	Last Reward: 0.00	Last 20 Episodes Average Reward: 100.00		Running reward: 101.00
# Episode 400 completed.	Last Reward: 100.00	Last 20 Episodes Average Reward: 125.00		Running reward: 111.09
# Episode 420 completed.	Last Reward: 0.00	Last 20 Episodes Average Reward: 120.00		Running reward: 110.94
# Episode 440 completed.	Last Reward: 0.00	Last 20 Episodes Average Reward: 270.00		Running reward: 207.46
# Episode 460 completed.	Last Reward: 0.00	Last 20 Episodes Average Reward: 115.00		Running reward: 137.09
# Episode 480 completed.	Last Reward: 100.00	Last 20 Episodes Average Reward: 90.00		Running reward: 107.90
# Episode 500 completed.	Last Reward: 200.00	Last 20 Episodes Average Reward: 90.00		Running reward: 95.63
# Episode 520 completed.	Last Reward: 300.00	Last 20 Episodes Average Reward: 125.00		Running reward: 112.47
# Episode 540 completed.	Last Reward: 0.00	Last 20 Episodes Average Reward: 50.00		Running reward: 72.38
# Episode 560 completed.	Last Reward: 0.00	Last 20 Episodes Average Reward: 165.00		Running reward: 126.78
# Episode 580 completed.	Last Reward: 200.00	Last 20 Episodes Average Reward: 130.00		Running reward: 124.12
# Episode 600 completed.	Last Reward: 700.00	Last 20 Episodes Average Reward: 320.00		Running reward: 259.56
# Episode 620 completed.	Last Reward: 0.00	Last 20 Episodes Average Reward: 135.00		Running reward: 175.25
# Episode 640 completed.	Last Reward: 200.00	Last 20 Episodes Average Reward: 140.00		Running reward: 158.90
# Episode 660 completed.	Last Reward: 0.00	Last 20 Episodes Average Reward: 135.00		Running reward: 136.90
# Episode 680 completed.	Last Reward: 200.00	Last 20 Episodes Average Reward: 170.00		Running reward: 165.49
# Episode 700 completed.	Last Reward: 100.00	Last 20 Episodes Average Reward: 150.00		Running reward: 161.30
# Episode 720 completed.	Last Reward: 0.00	Last 20 Episodes Average Reward: 100.00		Running reward: 118.64
# Episode 740 completed.	Last Reward: 0.00	Last 20 Episodes Average Reward: 65.00		Running reward: 85.33
# Episode 760 completed.	Last Reward: 100.00	Last 20 Episodes Average Reward: 135.00		Running reward: 115.11
# Episode 780 completed.	Last Reward: 0.00	Last 20 Episodes Average Reward: 100.00		Running reward: 103.87
# Episode 800 completed.	Last Reward: 100.00	Last 20 Episodes Average Reward: 155.00		Running reward: 127.96
# Episode 820 completed.	Last Reward: 100.00	Last 20 Episodes Average Reward: 140.00		Running reward: 148.82
# Episode 840 completed.	Last Reward: 0.00	Last 20 Episodes Average Reward: 160.00		Running reward: 151.55
# Episode 860 completed.	Last Reward: 300.00	Last 20 Episodes Average Reward: 195.00		Running reward: 184.64
# Episode 880 completed.	Last Reward: 0.00	Last 20 Episodes Average Reward: 160.00		Running reward: 174.13
# Episode 900 completed.	Last Reward: 200.00	Last 20 Episodes Average Reward: 205.00		Running reward: 197.63
# Episode 920 completed.	Last Reward: 400.00	Last 20 Episodes Average Reward: 130.00		Running reward: 153.75
# Episode 940 completed.	Last Reward: 300.00	Last 20 Episodes Average Reward: 260.00		Running reward: 209.95
# Episode 960 completed.	Last Reward: 100.00	Last 20 Episodes Average Reward: 150.00		Running reward: 169.01
# Episode 980 completed.	Last Reward: 0.00	Last 20 Episodes Average Reward: 180.00		Running reward: 161.99
# Episode 1000 completed.	Last Reward: 300.00	Last 20 Episodes Average Reward: 245.00		Running reward: 206.09
# Episode 1020 completed.	Last Reward: 200.00	Last 20 Episodes Average Reward: 195.00		Running reward: 193.83
# Episode 1040 completed.	Last Reward: 0.00	Last 20 Episodes Average Reward: 85.00		Running reward: 121.63
# Episode 1060 completed.	Last Reward: 200.00	Last 20 Episodes Average Reward: 135.00		Running reward: 130.87
# Episode 1080 completed.	Last Reward: 600.00	Last 20 Episodes Average Reward: 200.00		Running reward: 175.31
# Episode 1100 completed.	Last Reward: 100.00	Last 20 Episodes Average Reward: 210.00		Running reward: 193.32
# Episode 1120 completed.	Last Reward: 100.00	Last 20 Episodes Average Reward: 170.00		Running reward: 175.24
# Episode 1140 completed.	Last Reward: 200.00	Last 20 Episodes Average Reward: 65.00		Running reward: 103.54
# Episode 1160 completed.	Last Reward: 200.00	Last 20 Episodes Average Reward: 70.00		Running reward: 86.30
# Episode 1180 completed.	Last Reward: 0.00	Last 20 Episodes Average Reward: 65.00		Running reward: 68.35
# Episode 1200 completed.	Last Reward: 0.00	Last 20 Episodes Average Reward: 60.00		Running reward: 64.49
# Episode 1220 completed.	Last Reward: 200.00	Last 20 Episodes Average Reward: 80.00		Running reward: 77.78
# Episode 1240 completed.	Last Reward: 100.00	Last 20 Episodes Average Reward: 125.00		Running reward: 105.13
# Episode 1260 completed.	Last Reward: 0.00	Last 20 Episodes Average Reward: 90.00		Running reward: 99.62
# Episode 1280 completed.	Last Reward: 0.00	Last 20 Episodes Average Reward: 100.00		Running reward: 94.49
# Episode 1300 completed.	Last Reward: 200.00	Last 20 Episodes Average Reward: 135.00		Running reward: 124.33
# Episode 1320 completed.	Last Reward: 200.00	Last 20 Episodes Average Reward: 135.00		Running reward: 127.85
# Episode 1340 completed.	Last Reward: 200.00	Last 20 Episodes Average Reward: 185.00		Running reward: 166.56
# Episode 1360 completed.	Last Reward: 200.00	Last 20 Episodes Average Reward: 105.00		Running reward: 123.18
# Episode 1380 completed.	Last Reward: 0.00	Last 20 Episodes Average Reward: 110.00		Running reward: 112.83
# Episode 1400 completed.	Last Reward: 100.00	Last 20 Episodes Average Reward: 170.00		Running reward: 165.37
# Episode 1420 completed.	Last Reward: 0.00	Last 20 Episodes Average Reward: 140.00		Running reward: 150.93
# Episode 1440 completed.	Last Reward: 200.00	Last 20 Episodes Average Reward: 200.00		Running reward: 190.39
# Episode 1460 completed.	Last Reward: 800.00	Last 20 Episodes Average Reward: 170.00		Running reward: 179.26
# Episode 1480 completed.	Last Reward: 0.00	Last 20 Episodes Average Reward: 95.00		Running reward: 118.18
# Episode 1500 completed.	Last Reward: 0.00	Last 20 Episodes Average Reward: 55.00		Running reward: 71.44
# Recompensa obtenida en el episodio: 17500.0
# Moviepy - Building video temp-{start}.mp4.
# Moviepy - Writing video temp-{start}.mp4
# Moviepy - Done !
# Moviepy - video ready temp-{start}.mp4
# <video controls  >
#  <source src="data:video/mp4;base64,..." type="video/mp4">
#  Your browser does not support the video tag.
#  </video>

# %%
# Entrenamiento de REINFORCE con baseline como estimación de la función de valor (use_baseline=3)

# =====================================================
# COMPLETAR ===========================================

print("Entrenamiento CON baseline = red neuronal de valor V(s) (use_baseline=3).")
print("\n")

# Se inicializa el agente con una segunda red neuronal que aproxima V(s)
# Las tasas de aprendizaje siguen las recomendaciones del enunciado
agente_atlantis3 = REINFORCE_atla(
    use_baseline=3,
    learning_rate_reinforce=1e-5,
    learning_rate_baseline=1e-6,
    gamma=1,
    max_steps_per_episode=5000,
    max_training_episodes=1500
)

# Entrenamiento del agente
agente_atlantis3.train()

# Curva de aprendizaje (recompensa promedio cada 20 episodios)
agente_atlantis3.graph_training()

# Validación visual de la política aprendida
agente_atlantis3.video()

# Se guarda la política y la red de valor entrenadas
torch.save(agente_atlantis3.policy.state_dict(), 'policy_agente3.pth')
torch.save(agente_atlantis3.value_function_estimator.state_dict(), 'value_agente3.pth')

# =====================================================
# Out:
# Entrenamiento CON baseline = red neuronal de valor V(s) (use_baseline=3).
# WARNING:py.warnings:/usr/local/lib/python3.12/dist-packages/jupyter_client/session.py:203: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   return datetime.utcnow().replace(tzinfo=utc)
# Episode 20 completed.	Last Reward: 100.00	Last 20 Episodes Average Reward: 75.00		Running reward: 45.04
# WARNING:py.warnings:/tmp/ipykernel_1676/2153742008.py:178: UserWarning: Using a target size (torch.Size([1])) that is different to the input size (torch.Size([])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   value_function_estimator_loss = F.mse_loss(predicted_values, returns)
# Episode 40 completed.	Last Reward: 0.00	Last 20 Episodes Average Reward: 80.00		Running reward: 67.46
# Episode 60 completed.	Last Reward: 100.00	Last 20 Episodes Average Reward: 90.00		Running reward: 87.45
# Episode 80 completed.	Last Reward: 500.00	Last 20 Episodes Average Reward: 195.00		Running reward: 166.92
# Episode 100 completed.	Last Reward: 0.00	Last 20 Episodes Average Reward: 225.00		Running reward: 211.89
# Episode 120 completed.	Last Reward: 100.00	Last 20 Episodes Average Reward: 155.00		Running reward: 171.07
# Episode 140 completed.	Last Reward: 0.00	Last 20 Episodes Average Reward: 170.00		Running reward: 175.50
# Episode 160 completed.	Last Reward: 500.00	Last 20 Episodes Average Reward: 170.00		Running reward: 185.01
# Episode 180 completed.	Last Reward: 0.00	Last 20 Episodes Average Reward: 170.00		Running reward: 175.48
# Episode 200 completed.	Last Reward: 0.00	Last 20 Episodes Average Reward: 145.00		Running reward: 162.06
# Episode 220 completed.	Last Reward: 0.00	Last 20 Episodes Average Reward: 330.00		Running reward: 256.56
# Episode 240 completed.	Last Reward: 0.00	Last 20 Episodes Average Reward: 180.00		Running reward: 199.43
# Episode 260 completed.	Last Reward: 300.00	Last 20 Episodes Average Reward: 180.00		Running reward: 193.54
# Episode 280 completed.	Last Reward: 200.00	Last 20 Episodes Average Reward: 220.00		Running reward: 214.59
# Episode 300 completed.	Last Reward: 100.00	Last 20 Episodes Average Reward: 160.00		Running reward: 186.26
# Episode 320 completed.	Last Reward: 200.00	Last 20 Episodes Average Reward: 195.00		Running reward: 195.97
# Episode 340 completed.	Last Reward: 200.00	Last 20 Episodes Average Reward: 160.00		Running reward: 162.06
# Episode 360 completed.	Last Reward: 300.00	Last 20 Episodes Average Reward: 170.00		Running reward: 155.69
# Episode 380 completed.	Last Reward: 200.00	Last 20 Episodes Average Reward: 130.00		Running reward: 143.85
# Episode 400 completed.	Last Reward: 0.00	Last 20 Episodes Average Reward: 110.00		Running reward: 105.14
# Episode 420 completed.	Last Reward: 100.00	Last 20 Episodes Average Reward: 90.00		Running reward: 100.34
# Episode 440 completed.	Last Reward: 0.00	Last 20 Episodes Average Reward: 60.00		Running reward: 75.98
# Episode 460 completed.	Last Reward: 0.00	Last 20 Episodes Average Reward: 170.00		Running reward: 130.07
# Episode 480 completed.	Last Reward: 200.00	Last 20 Episodes Average Reward: 275.00		Running reward: 229.94
# Episode 500 completed.	Last Reward: 200.00	Last 20 Episodes Average Reward: 240.00		Running reward: 243.62
# Episode 520 completed.	Last Reward: 500.00	Last 20 Episodes Average Reward: 150.00		Running reward: 181.70
# Episode 540 completed.	Last Reward: 200.00	Last 20 Episodes Average Reward: 200.00		Running reward: 195.19
# Episode 560 completed.	Last Reward: 0.00	Last 20 Episodes Average Reward: 185.00		Running reward: 194.75
# Episode 580 completed.	Last Reward: 0.00	Last 20 Episodes Average Reward: 270.00		Running reward: 220.47
# Episode 600 completed.	Last Reward: 0.00	Last 20 Episodes Average Reward: 205.00		Running reward: 186.06
# Episode 620 completed.	Last Reward: 500.00	Last 20 Episodes Average Reward: 130.00		Running reward: 159.00
# Episode 640 completed.	Last Reward: 0.00	Last 20 Episodes Average Reward: 125.00		Running reward: 132.65
# Episode 660 completed.	Last Reward: 100.00	Last 20 Episodes Average Reward: 235.00		Running reward: 198.39
# Episode 680 completed.	Last Reward: 100.00	Last 20 Episodes Average Reward: 160.00		Running reward: 172.54
# Episode 700 completed.	Last Reward: 0.00	Last 20 Episodes Average Reward: 160.00		Running reward: 158.31
# Episode 720 completed.	Last Reward: 500.00	Last 20 Episodes Average Reward: 200.00		Running reward: 186.09
# Episode 740 completed.	Last Reward: 100.00	Last 20 Episodes Average Reward: 125.00		Running reward: 156.94
# Episode 760 completed.	Last Reward: 200.00	Last 20 Episodes Average Reward: 225.00		Running reward: 216.88
# Episode 780 completed.	Last Reward: 0.00	Last 20 Episodes Average Reward: 110.00		Running reward: 143.20
# Episode 800 completed.	Last Reward: 100.00	Last 20 Episodes Average Reward: 165.00		Running reward: 153.56
# Episode 820 completed.	Last Reward: 100.00	Last 20 Episodes Average Reward: 145.00		Running reward: 140.66
# Episode 840 completed.	Last Reward: 0.00	Last 20 Episodes Average Reward: 185.00		Running reward: 166.91
# Episode 860 completed.	Last Reward: 900.00	Last 20 Episodes Average Reward: 275.00		Running reward: 255.18
# Episode 880 completed.	Last Reward: 0.00	Last 20 Episodes Average Reward: 165.00		Running reward: 193.47
# Episode 900 completed.	Last Reward: 200.00	Last 20 Episodes Average Reward: 155.00		Running reward: 166.74
# Episode 920 completed.	Last Reward: 100.00	Last 20 Episodes Average Reward: 135.00		Running reward: 144.51
# Episode 940 completed.	Last Reward: 100.00	Last 20 Episodes Average Reward: 140.00		Running reward: 137.95
# Episode 960 completed.	Last Reward: 300.00	Last 20 Episodes Average Reward: 155.00		Running reward: 148.30
# Episode 980 completed.	Last Reward: 0.00	Last 20 Episodes Average Reward: 145.00		Running reward: 150.13
# Episode 1000 completed.	Last Reward: 0.00	Last 20 Episodes Average Reward: 180.00		Running reward: 166.89
# Episode 1020 completed.	Last Reward: 0.00	Last 20 Episodes Average Reward: 255.00		Running reward: 221.52
# Episode 1040 completed.	Last Reward: 100.00	Last 20 Episodes Average Reward: 175.00		Running reward: 166.32
# Episode 1060 completed.	Last Reward: 0.00	Last 20 Episodes Average Reward: 135.00		Running reward: 145.26
# Episode 1080 completed.	Last Reward: 0.00	Last 20 Episodes Average Reward: 90.00		Running reward: 107.27
# Episode 1100 completed.	Last Reward: 200.00	Last 20 Episodes Average Reward: 155.00		Running reward: 139.00
# Episode 1120 completed.	Last Reward: 200.00	Last 20 Episodes Average Reward: 300.00		Running reward: 236.47
# Episode 1140 completed.	Last Reward: 0.00	Last 20 Episodes Average Reward: 225.00		Running reward: 214.38
# Episode 1160 completed.	Last Reward: 100.00	Last 20 Episodes Average Reward: 255.00		Running reward: 240.83
# Episode 1180 completed.	Last Reward: 0.00	Last 20 Episodes Average Reward: 230.00		Running reward: 227.58
# Episode 1200 completed.	Last Reward: 100.00	Last 20 Episodes Average Reward: 175.00		Running reward: 189.48
# Episode 1220 completed.	Last Reward: 100.00	Last 20 Episodes Average Reward: 160.00		Running reward: 166.13
# Episode 1240 completed.	Last Reward: 600.00	Last 20 Episodes Average Reward: 180.00		Running reward: 187.19
# Episode 1260 completed.	Last Reward: 0.00	Last 20 Episodes Average Reward: 180.00		Running reward: 176.11
# Episode 1280 completed.	Last Reward: 100.00	Last 20 Episodes Average Reward: 250.00		Running reward: 217.63
# Episode 1300 completed.	Last Reward: 400.00	Last 20 Episodes Average Reward: 180.00		Running reward: 184.15
# Episode 1320 completed.	Last Reward: 0.00	Last 20 Episodes Average Reward: 125.00		Running reward: 146.05
# Episode 1340 completed.	Last Reward: 0.00	Last 20 Episodes Average Reward: 150.00		Running reward: 140.81
# Episode 1360 completed.	Last Reward: 0.00	Last 20 Episodes Average Reward: 250.00		Running reward: 206.93
# Episode 1380 completed.	Last Reward: 200.00	Last 20 Episodes Average Reward: 280.00		Running reward: 254.50
# Episode 1400 completed.	Last Reward: 400.00	Last 20 Episodes Average Reward: 210.00		Running reward: 234.88
# Episode 1420 completed.	Last Reward: 100.00	Last 20 Episodes Average Reward: 185.00		Running reward: 211.46
# Episode 1440 completed.	Last Reward: 400.00	Last 20 Episodes Average Reward: 205.00		Running reward: 216.00
# Episode 1460 completed.	Last Reward: 400.00	Last 20 Episodes Average Reward: 215.00		Running reward: 214.52
# Episode 1480 completed.	Last Reward: 0.00	Last 20 Episodes Average Reward: 315.00		Running reward: 278.36
# Episode 1500 completed.	Last Reward: 200.00	Last 20 Episodes Average Reward: 170.00		Running reward: 204.28
# Recompensa obtenida en el episodio: 13900.0
# Moviepy - Building video temp-{start}.mp4.
# Moviepy - Writing video temp-{start}.mp4
# Moviepy - Done !
# Moviepy - video ready temp-{start}.mp4
# <video controls  >
#  <source src="data:video/mp4;base64,..." type="video/mp4">
#  Your browser does not support the video tag.
#  </video>

# %% [markdown]
# # Preguntas de análisis
#
# Teniendo en cuenta lo observado en las pruebas anteriores, reflexione acerca de las siguientes preguntas:
#
# *   ¿Es REINFORCE un algoritmo estable?
#
# *   ¿Es siempre bueno usar cualquier <i>baseline</i> en REINFORCE?
#
# *   ¿Qué efecto tiene normalizar los retornos? ¿Es similar a utilizar <i>baselines</i>?

# %% [markdown]
# ## Respuestas y Análisis
#
# A continuación se responden las preguntas planteadas anteriormente, experimentalmente en los cuatro entrenamientos realizados (`use_baseline = 0, 1, 2, 3`).
#
# ### 1. ¿Es REINFORCE un algoritmo estable?
#
# **No, REINFORCE no es un algoritmo estable**, y esto se evidencia tanto en la teoría como en los experimentos realizados.
#
# - **Razón teórica:** REINFORCE es un método de Monte Carlo que estima el gradiente de la política utilizando el retorno completo del episodio $G_t$. Este retorno es una variable aleatoria con **varianza muy alta**, especialmente en ambientes con episodios largos como *Atlantis* (hasta 5,000 pasos) y con recompensas dispersas.
#
# - **Evidencia experimental:** En el entrenamiento con `use_baseline=0` (sin baseline), la curva de recompensa promedio cada 20 episodios presenta fuertes oscilaciones y, a pesar de los 1,500 episodios de entrenamiento, el agente termina con una recompensa de validación cercana a **12,000 puntos**, apenas por encima de la política uniformemente aleatoria (~10,000 puntos). Esto refleja que las actualizaciones no logran aprender una mejora significativa de manera consistente.
#
#   - Incluso usando `use_baseline=1`, `2` o `3`, la curva sigue presentando ruido considerable, aunque con tendencia más clara hacia recompensas altas. Esto confirma que **ninguna variante de REINFORCE produce una curva monótonamente creciente**.
#
# - **Factores que agravan la inestabilidad observada:**
#   1. **Sensibilidad a la tasa de aprendizaje:**
#   2. **Dependencia del muestreo de trayectorias completas:**
#   3. **Política estocástica:**
#
# **Conclusión:** REINFORCE es un algoritmo **conceptualmente correcto pero inestable en la práctica**. Por esta razón, en aplicaciones reales se prefieren variantes como Actor-Critic, A2C/A3C o PPO.
# ---
#
# ### 2. ¿Es siempre bueno usar cualquier *baseline* en REINFORCE?
#
# **No, no cualquier baseline es útil.** El teorema del gradiente de política garantiza que **cualquier función $b(S_t)$ que dependa solo del estado** (no de la acción) deja al gradiente **insesgado**, es decir, $\mathbb{E}\!\left[(G_t-b(S_t))\nabla \log \pi(A_t|S_t,\theta)\right] = \nabla J(\theta)$. Sin embargo, para que el baseline sea **útil** debe además **reducir la varianza** del estimador del gradiente. Comparando los tres baselines del notebook:
#
# #### `use_baseline=2`: Promedio de los retornos como baseline
# - Es una **constante** (un promedio escalar) que no depende del estado.
# - Aunque resta un valor a $G_t$, no está alineada con la estructura del problema: estados intrínsecamente "fáciles" siguen recibiendo advantage positiva y estados "difíciles" reciben advantage negativa, sin distinguir verdaderamente acciones buenas de malas dentro de cada estado.
# - En la práctica se observa que la mejora respecto a `use_baseline=0` es **marginal**, y a veces incluso similar al caso sin baseline.
# - Por lo tanto, este baseline **no recomendado** se usa principalmente con fines pedagógicos.
#
# #### `use_baseline=3`: Función de valor $V(s)$ aproximada por red neuronal
# - Es el baseline **teóricamente más sólido**, pues sí depende del estado y se acerca al óptimo $b^*(s)=\mathbb{E}[G_t|S_t=s]$.
# - La advantage $A_t = G_t - V(S_t)$ tiene varianza considerablemente menor que $G_t$.
# - En el experimento se aprecia una curva de aprendizaje más suave y mayor recompensa final que en los casos `0` y `2`.
# - **Sin embargo, también presenta riesgos:**
#   1. La red de valor debe entrenarse con cuidado; si tiene errores grandes, $V(s)$ se convierte en una fuente adicional de ruido.
#   2. Aumenta el costo computacional (otra red, otro optimizador).
#   3. Si las tasas de aprendizaje (`learning_rate_baseline`) no están bien ajustadas, la convergencia se ve afectada.
#
# #### Caso problemático: baselines que dependen de la acción
# - Si el baseline dependiera de la acción tomada (por ejemplo, un $Q(s,a)$), el gradiente **dejaría de ser insesgado** y el algoritmo estaría aprendiendo algo distinto al gradiente real de $J(\theta)$.
#
# **Conclusión:** un buen baseline debe (i) depender solo del estado, (ii) aproximar bien el retorno esperado en ese estado y (iii) ser robusto a la estimación. La opción `use_baseline=3` cumple los tres criterios y es claramente superior, mientras que `use_baseline=2` es la peor opción de las disponibles.
#
# ---
#
# ### 3. ¿Qué efecto tiene normalizar los retornos? ¿Es similar a utilizar *baselines*?
#
# #### Efecto de la normalización (`use_baseline=1`)
# La normalización transforma el retorno como:
# $$\tilde{G_t} = \frac{G_t - \mu_G}{\sigma_G + \epsilon}$$
#
# donde $\mu_G$ y $\sigma_G$ son la media y desviación estándar de los retornos del episodio. Esto produce dos efectos:
#
# 1. **Centrado:** restar $\mu_G$ es equivalente a usar un baseline constante igual al promedio de los retornos del episodio (similar a `use_baseline=2`).
# 2. **Escalado:** dividir por $\sigma_G$ pone los retornos en una escala estándar. Esto **reduce drásticamente la magnitud del gradiente** y, en consecuencia, evita actualizaciones excesivamente grandes que provocarían colapso de la política.
#
# En los experimentos, `use_baseline=1` suele dar la **curva más estable de las tres opciones de baseline**, especialmente cuando la magnitud de las recompensas es muy variable, como ocurre en *Atlantis* (recompensas de 100 o 200 puntos en pasos esporádicos).
#
# #### ¿Es lo mismo que usar un baseline?
# **No es exactamente lo mismo, aunque produce un efecto práctico parecido.** Las diferencias clave son:
#
# | Aspecto | Baseline clásico ($b(S_t)$) | Normalización del retorno |
# |---|---|---|
# | **Sesgo del gradiente** | **Insesgado**, garantizado por el teorema del gradiente de política | **Sesgado** (la división por $\sigma_G$ altera la dirección del gradiente) |
# | **Reducción de varianza** | Sí, si $b(S_t)\approx \mathbb{E}[G_t|S_t]$ | Sí, mediante reescalado |
# | **Dependencia del estado** | Idealmente sí (`use_baseline=3`) | No, $\mu_G$ y $\sigma_G$ son estadísticos del episodio completo |
# | **Costo computacional** | Alto si requiere red de valor | Mínimo (estadísticas en línea) |
# | **Justificación teórica** | Estricta (teorema PG) | Heurística práctica |
#
# #### Comparación experimental resumida
#
# | Configuración | Estabilidad de la curva | Recompensa final esperada | Costo computacional |
# |---|---|---|---|
# | `use_baseline=0` (sin baseline) | Baja | ~12,000 (similar a aleatoria) | Bajo |
# | `use_baseline=1` (normalización) | Alta | Mejora notable (>15,000) | Bajo |
# | `use_baseline=2` (promedio) | Media (apenas mejor que 0) | Marginal sobre 0 | Bajo |
# | `use_baseline=3` (red de valor) | Alta | Mejor o comparable a 1 | Alto |
#
# **Conclusión:** la normalización es una **técnica heurística muy efectiva** que en la práctica imita los beneficios de un baseline (reduce varianza y estabiliza el aprendizaje), pero no es teóricamente equivalente: introduce un pequeño sesgo en el gradiente. Usar `use_baseline=1` y `use_baseline=3` simultáneamente —es decir, calcular ventajas $G_t - V(s)$ y luego normalizarlas— es de hecho la receta estándar en algoritmos modernos como **A2C** y **PPO**, lo que confirma que ambas técnicas son complementarias y no excluyentes.

# %% [markdown]
# # Referencias
#
# [1] Sutton, R. S. and Barto, A. G. (2018). Reinforcement Learning: An Introduction. The MIT Press, second edition.
#
# [2] Gym Documentation, Atlantis. `https://gymnasium.farama.org/v0.28.1/environments/atari/atlantis/`
#
# [3] PyTorch REINFORCE example. `https://github.com/pytorch/examples/blob/main/reinforcement_learning/reinforce.py`
